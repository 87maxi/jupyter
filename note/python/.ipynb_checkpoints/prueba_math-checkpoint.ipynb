# %%
def fibonacci_of(n):
     if n in {0, 1}:  # Base case
         return n
     return fibonacci_of(n - 1) + fibonacci_of(n - 2)  # Recursive cas

# %%
[ i for n in range(150) for i in fibonacci_of(n) ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 [ i for n in range(150) for i in fibonacci_of(n) ]
#
# Cell In[6], line 1, in <listcomp>(.0)
# ----> 1 [ i for n in range(150) for i in fibonacci_of(n) ]
#
# Cell In[3], line 4, in fibonacci_of(n)
#       2 if n in {0, 1}:  # Base case
#       3     return n
# ----> 4 yield fibonacci_of(n - 1) + fibonacci_of(n - 2)
#
# TypeError: unsupported operand type(s) for +: 'generator' and 'generator'

# %%
import qu


threads = list()
for n in range(150):
    
    x = threading.Thread(target=fibonacci_of, args=(n,))
    threads.append(x)
    x.start()


print(threads.)
